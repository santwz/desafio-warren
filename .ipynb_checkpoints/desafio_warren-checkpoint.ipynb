# %% [markdown]
# <div align="center">
#     <img src="logo/logo_warren_terracota.webp" alt="Logo Warren Terracota" width="400"> </div>
# </div>
#
# **Solução por Wallace Santo.**

# %%
#Importando bibliotecas iniciais
import yfinance as yf # Para obter os dados do Yahoo Finance
import pandas as pd # Para utilizar os dataframes
import matplotlib.pyplot as plt #Criar gráficos

# %%
# Datas no formato americano(compatível com o Yahoo Finance)
data_inicio = "2024-02-20"
data_final = "2024-04-09"

# Definindo o código do ativo na bolsa
codigo = "LFTS11.SA"

# Baixando os dados históricos do ativo
historico_lfts11 = yf.download(codigo, start=data_inicio, end=data_final)

# Removendo 'Adj Close', por ser indexado em Selic, não há diferença real entre Close e Adj Close. 
# Removendo 'Volume', pois o algoritmo TWAP não utiliza essa métrica
historico_lfts11 = historico_lfts11.drop(columns=['Adj Close', 'Volume'])

# Criando uma coluna com a média de 'Open', 'High', 'low' e 'Close' de cada dia
historico_lfts11['Mean'] = historico_lfts11.mean(axis=1)

# Visualiazndo o histórico
historico_lfts11
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close        Mean
# Date
# 2024-02-20  116.620003  116.650002  116.620003  116.620003  116.627502
# 2024-02-21  116.629997  116.699997  116.629997  116.680000  116.659998
# 2024-02-22  116.680000  116.750000  116.669998  116.730003  116.707500
# 2024-02-23  116.750000  116.809998  116.610001  116.800003  116.742500
# 2024-02-26  116.800003  116.849998  116.779999  116.830002  116.815001
# 2024-02-27  116.830002  116.879997  116.800003  116.870003  116.845001
# 2024-02-28  116.910004  116.940002  116.910004  116.910004  116.917503
# 2024-02-29  116.860001  116.980003  116.699997  116.959999  116.875000
# 2024-03-01  116.930000  117.019997  116.900002  117.000000  116.962500
# 2024-03-04  117.000000  117.080002  116.699997  117.050003  116.957500
# 2024-03-05  117.080002  117.129997  117.080002  117.129997  117.105000
# 2024-03-06  117.139999  117.180000  117.129997  117.150002  117.150000
# 2024-03-07  117.139999  117.230003  117.139999  117.199997  117.177500
# 2024-03-08  117.160004  117.279999  117.160004  117.260002  117.215002
# 2024-03-11  117.260002  117.330002  117.239998  117.309998  117.285000
# 2024-03-12  117.300003  117.370003  117.300003  117.370003  117.335003
# 2024-03-13  117.379997  117.480003  117.360001  117.360001  117.395000
# 2024-03-14  117.339996  117.480003  117.339996  117.480003  117.410000
# 2024-03-15  117.500000  117.529999  117.489998  117.510002  117.507500
# 2024-03-18  117.470001  117.580002  117.180000  117.559998  117.447500
# 2024-03-19  117.550003  117.620003  117.489998  117.599998  117.565001
# 2024-03-20  117.599998  117.680000  117.570000  117.650002  117.625000
# 2024-03-21  117.650002  117.730003  117.650002  117.699997  117.682501
# 2024-03-22  117.730003  117.900002  117.489998  117.779999  117.725000
# 2024-03-25  117.760002  117.849998  117.739998  117.830002  117.795000
# 2024-03-26  117.760002  117.870003  117.750000  117.839996  117.805000
# 2024-03-27  117.860001  117.919998  117.860001  117.900002  117.885000
# 2024-03-28  117.889999  117.959999  117.879997  117.949997  117.919998
# 2024-04-01  117.919998  118.029999  117.919998  118.029999  117.974998
# 2024-04-02  118.029999  118.070000  118.000000  118.050003  118.037500
# 2024-04-03  118.089996  118.110001  118.080002  118.089996  118.092499
# 2024-04-04  118.089996  118.349998  118.089996  118.129997  118.164997
# 2024-04-05  118.139999  118.209999  118.139999  118.199997  118.172499
# 2024-04-08  118.190002  118.269997  118.190002  118.239998  118.222500

# %%
# Calculando o TWAP
twap = historico_lfts11['Mean'].mean()
twap
# Out:
# 117.40602953293744

# %%
# Abrindo a planilha do desafio para automação
automacao = pd.read_excel('planilha_de_saldo_para_automao.xlsx')

# %%
# Importando a biblioteca math para trabalhamos apenas com valores inteiros
import math

# Definindo o valor de compra ou venda para o TWAP encontrado anteriormente
valor_lfts11 = twap

# Função para calcular a operação de compra ou venda
def operacao(saldo):
    #Verificando se o saldo é negativo
    if saldo < 0:
        quantidade_venda = abs(saldo) / valor_lfts11
        #Usando a função teto para garantir todos os casos
        quantidade_venda = math.ceil(quantidade_venda)
        return f"Vender {quantidade_venda} cota(s)"
    else:
        quantidade_compra = saldo / valor_lfts11
        #Usando a função piso para garantir que não fique com saldo negativo
        quantidade_compra = math.floor(quantidade_compra)
        return f"Comprar {quantidade_compra} cota(s)"

# Aplicando a função no dataframe
automacao['Operação'] = automacao['Vl. Total'].apply(operacao)

automacao
# Out:
#      Cod. Conta Local  Vl. Total             Operação
# 0             7261164     -49.53     Vender 1 cota(s)
# 1             7000076     -49.56     Vender 1 cota(s)
# 2             7123124     -49.57     Vender 1 cota(s)
# 3             7208960     -49.85     Vender 1 cota(s)
# 4             7347126     -50.49     Vender 1 cota(s)
# ..                ...        ...                  ...
# 162           6323907    1097.60    Comprar 9 cota(s)
# 163           7043567    1929.12   Comprar 16 cota(s)
# 164           7138784    4298.44   Comprar 36 cota(s)
# 165           7079721   10753.40   Comprar 91 cota(s)
# 166           7121898   14713.27  Comprar 125 cota(s)
#
# [167 rows x 3 columns]

# %%
# Separando a nossa operação em Tipo(Compra ou Venda), Quantidade e Unidade
automacao['Tipo'], automacao['Quantidade'], automacao['Unidade'] = zip(*automacao['Operação'].str.split().tolist())

# Retirando as colunas Operação e Unidade para deixar o DataFrame mais limpo
automacao = automacao.drop(columns=['Operação', 'Unidade'])

automacao
# Out:
#      Cod. Conta Local  Vl. Total     Tipo Quantidade
# 0             7261164     -49.53   Vender          1
# 1             7000076     -49.56   Vender          1
# 2             7123124     -49.57   Vender          1
# 3             7208960     -49.85   Vender          1
# 4             7347126     -50.49   Vender          1
# ..                ...        ...      ...        ...
# 162           6323907    1097.60  Comprar          9
# 163           7043567    1929.12  Comprar         16
# 164           7138784    4298.44  Comprar         36
# 165           7079721   10753.40  Comprar         91
# 166           7121898   14713.27  Comprar        125
#
# [167 rows x 4 columns]

# %%
# Abrindo o modelo_mesa que é o exemplo para o desafio
modelo_mesa = pd.read_excel('modelo_mesa_-_lfts11_-_exemplo_-_desafio_vba.xlsx')

# %%
# Visualizando o DataFrame
modelo_mesa
# Out:
#     C\V  Código  Nome  Qtd  Qtd Aberta    Preço  Cliente  Nome Cliente  \
# 0     C  LFTS11   NaN    1         NaN  MERCADO  6323847           NaN
# 1     C  LFTS11   NaN    1         NaN  MERCADO  6214012           NaN
# 2     C  LFTS11   NaN    1         NaN  MERCADO  6194123           NaN
# 3     C  LFTS11   NaN    1         NaN  MERCADO  6082801           NaN
# 4     C  LFTS11   NaN    1         NaN  MERCADO  6318720           NaN
# ..   ..     ...   ...  ...         ...      ...      ...           ...
# 475   C  LFTS11   NaN    3         NaN  MERCADO  4193422           NaN
# 476   C  LFTS11   NaN    9         NaN  MERCADO  4210087           NaN
# 477   C  LFTS11   NaN   14         NaN  MERCADO  4243037           NaN
# 478   C  LFTS11   NaN   25         NaN  MERCADO  4144588           NaN
# 479   C  LFTS11   NaN   75         NaN  MERCADO  4275255           NaN
#
#      Agente de Custódia  Conta de Custódia  Código da Carteira   N°
# 0                   NaN                NaN                 NaN    1
# 1                   NaN                NaN                 NaN    2
# 2                   NaN                NaN                 NaN    3
# 3                   NaN                NaN                 NaN    4
# 4                   NaN                NaN                 NaN    5
# ..                  ...                ...                 ...  ...
# 475                 NaN                NaN                 NaN  476
# 476                 NaN                NaN                 NaN  477
# 477                 NaN                NaN                 NaN  478
# 478                 NaN                NaN                 NaN  479
# 479                 NaN                NaN                 NaN  480
#
# [480 rows x 12 columns]

# %%
# Adicionando cada linha do DataFrame 'automacao', que era o desafio
for index, row in automacao.iterrows():
    # Definir se é C ou V com base na coluna 'Tipo'
    cv = 'C' if 'Comprar' in row['Tipo'] else 'V'

    # Iterando a partir do indíce final da planilha modelo_mesa 
    numero = 481 + index

    # Criando uma linha como um DataFrame para concatenar
    nova_linha = pd.DataFrame({
        'C\V': [cv],
        'Código': ['LFTS11'],
        'Qtd': [row['Quantidade']],
        'Qtd Aberta': [None],
        'Preço': ['MERCADO'],
        'Cliente': [row['Cod. Conta Local']],  
        'Nome Cliente': [None],
        'Agente de Custódia': [None],
        'Conta de Custódia': [None],
        'Código da Carteira': [None],
        'N°': [numero]
    })
    
    
    # Concatenar a nova linha ao DataFrame da planilha modelo_mesa
    modelo_mesa = pd.concat([modelo_mesa, nova_linha], ignore_index=True)

# %%
#Visualizando o DataFrame
modelo_mesa
# Out:
#     C\V  Código  Nome  Qtd Qtd Aberta    Preço  Cliente Nome Cliente  \
# 0     C  LFTS11   NaN    1        NaN  MERCADO  6323847          NaN
# 1     C  LFTS11   NaN    1        NaN  MERCADO  6214012          NaN
# 2     C  LFTS11   NaN    1        NaN  MERCADO  6194123          NaN
# 3     C  LFTS11   NaN    1        NaN  MERCADO  6082801          NaN
# 4     C  LFTS11   NaN    1        NaN  MERCADO  6318720          NaN
# ..   ..     ...   ...  ...        ...      ...      ...          ...
# 642   C  LFTS11   NaN    9        NaN  MERCADO  6323907          NaN
# 643   C  LFTS11   NaN   16        NaN  MERCADO  7043567          NaN
# 644   C  LFTS11   NaN   36        NaN  MERCADO  7138784          NaN
# 645   C  LFTS11   NaN   91        NaN  MERCADO  7079721          NaN
# 646   C  LFTS11   NaN  125        NaN  MERCADO  7121898          NaN
#
#     Agente de Custódia Conta de Custódia Código da Carteira   N°
# 0                  NaN               NaN                NaN    1
# 1                  NaN               NaN                NaN    2
# 2                  NaN               NaN                NaN    3
# 3                  NaN               NaN                NaN    4
# 4                  NaN               NaN                NaN    5
# ..                 ...               ...                ...  ...
# 642                NaN               NaN                NaN  643
# 643                NaN               NaN                NaN  644
# 644                NaN               NaN                NaN  645
# 645                NaN               NaN                NaN  646
# 646                NaN               NaN                NaN  647
#
# [647 rows x 12 columns]

# %%
# Verificando o Dtype 
modelo_mesa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   C\V                 647 non-null    object
#  1   Código              647 non-null    object
#  2   Nome                0 non-null      float64
#  3   Qtd                 647 non-null    object
#  4   Qtd Aberta          0 non-null      object
#  5   Preço               647 non-null    object
#  6   Cliente             647 non-null    int64
#  7   Nome Cliente        0 non-null      object
#  8   Agente de Custódia  0 non-null      object
#  9   Conta de Custódia   0 non-null      object
#  10  Código da Carteira  0 non-null      object
#  11  N°                  647 non-null    int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 60.8+ KB

# %%
# Modificando os tipos para facilitar o manuseio ao exportar para o Excel
modelo_mesa['Qtd'] = pd.to_numeric(modelo_mesa['Qtd'], errors='coerce').astype(int)
modelo_mesa['Preço'] = pd.to_numeric(modelo_mesa['Preço'], errors='coerce').astype(float)

# %%
# Verificando quanto foi Comprado ou Vendido, dado o TWAP

# Valor por unidade
valor_por_unidade = twap

# Filtrar apenas as linhas em que 'C\V' é igual a 'C'
compras = modelo_mesa[modelo_mesa['C\V'] == 'C']

# Somar a quantidade para todas as compras
quantidade_compras = compras['Qtd'].sum()

# Filtrar apenas as linhas em que 'C\V' é igual a 'V'
vendas = modelo_mesa[modelo_mesa['C\V'] == 'V']

# Somar a quantidade para todas as compras
quantidade_vendas = vendas['Qtd'].sum()

# Calcular o valor total de compra e venda
total_compra = quantidade_compras * valor_por_unidade
total_venda = quantidade_vendas * valor_por_unidade

# Plotar o gráfico de barras
valores = [total_compra, total_venda]
categorias = ['Compra', 'Venda']

plt.figure(figsize=(8, 6))
cores = ['#87CEEB', '#D3D3D3']  # Azul claro e cinza claro
bars = plt.bar(categorias, valores, color=cores)
plt.xlabel('Tipo de Operação')
plt.ylabel('Valor em Reais')
plt.title('Valor Total de Compra e Venda')

# Adicionar "R$" a cada número do eixo y
for bar, valor in zip(bars, valores):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), 'R$ {:.2f}'.format(valor), 
             va='bottom', ha='center', color='black')

plt.show()

# %%
# Exportando para Excel
nome_do_arquivo = 'modelo_mesa_desafio_resolvido.xlsx'
df.to_excel(nome_do_arquivo, index=False)

#Foi necessário adicionar a formatação manualmente

# %% [markdown]
# ### Com isso, completamos a primeira etapa do desafio, que era referente ao arquivo modelo_mesa.
#
# ### Contudo, precisamos atualizar o modelo_twap.

# %%
modelo_twap = pd.read_excel('modelo_twap_-_lfts11_-_exemplo_-_desafio_vba.xlsx')

# %%
modelo_twap
# Out:
#   ORDEM    LADO   ATIVO  QUANTIDADE  INICIO       FIM  PREÇO LIMITE
# 0  TWAP  COMPRA  LFTS11        1301     NaN  16:45:00           NaN
# 1  TWAP   VENDA  LFTS11           9     NaN  16:45:00           NaN

# %%
# A nova quantidade de COMPRA é dada por quantidade_compras
# A nova quantidade de VENDA é dada por quantidade_vendas

# Alterando diretamente, teremos

modelo_twap['QUANTIDADE'] = [quantidade_compras, quantidade_vendas]

# Visualizando modelo_twap atualizado

modelo_twap
# Out:
#   ORDEM    LADO   ATIVO  QUANTIDADE  INICIO       FIM  PREÇO LIMITE
# 0  TWAP  COMPRA  LFTS11        1626     NaN  16:45:00           NaN
# 1  TWAP   VENDA  LFTS11          14     NaN  16:45:00           NaN

# %%
# Exportando para o Excel

nome_do_arquivo = 'modelo_twap_desafio_resolvido.xlsx'
modelo_twap.to_excel(nome_do_arquivo, index=False)
